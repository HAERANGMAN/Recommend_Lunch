# %%
# 연습문제 11-1
# 네이버에서 "봄여행" 으로 검색하여 현재 화면에  보이는 내용을 파일로 저장하기
# 학습목표 1: 텍스트를 추출하여 화면에 출력하기
# Step 4. 현재 페이지에 있는 내용을 화면에 출력하기
#Step 1. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다
from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys

query_txt = input('크롤링할 키워드는 무엇입니까?: ')
f_name = input('검색 결과를 저장할 파일경로와 이름을 지정하세요(예:c:\\data\\test.txt): ')

#Step 2. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = r"C:\Users\201210961\Desktop\Coding\Python Webscraping\chromedriver_win32\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get("https://www.coupang.com/")
time.sleep(2)  #  창이 모두 열릴 때 까지 2초 기다립니다.

#Step 3. 검색창의 이름을 찾아서 검색어를 입력하고 검색을 실행합니다

element = driver.find_element_by_id("headerSearchKeyword")
element.send_keys(query_txt)

driver.find_element_by_id("headerSearchBtn").click()

time.sleep(1) 

full_html = driver.page_source

soup = BeautifulSoup(full_html, 'html.parser')

content_list = soup.find_all('div','name')
print(content_list)

for i in content_list:
    print(i.text.strip())
    print("\n")
# Out:
# 크롤링할 키워드는 무엇입니까?: 비타민
# 검색 결과를 저장할 파일경로와 이름을 지정하세요(예:c:\data\test.txt): C:\Users\201210961\Desktop\Coding\Python Webscraping\chromedriver_win32\test1.txt
# [<div class="name">뉴트리원 멀티비타민+미네랄+오메가3 3중 복합기능성 기초 건강 종합 영양제 + 활력환, 2box</div>, <div class="name">비타할로 온가족 멀티비타민 플러스 미네랄, 60정, 1개</div>, <div class="name">얼라이브 원스데일리 멀티비타민, 60정, 1개</div>, <div class="name">종근당건강 원데이21 멀티비타민 &amp; 미네랄, 60정, 2개</div>, <div class="name">닥터피플 쎈탁스 멀티 비타민 미네랄, 90정, 1개</div>, <div class="name">대웅제약 에너씨슬 콜레다운, 30정, 2개</div>, <div class="name">고려은단 비타민C 1000, 180정, 1개</div>, <div class="name">네이쳐스웨이 얼라이브! 맨 울트라 포텐시 멀티 비타민 타블렛 60개입, 1개</div>, <div class="name">한미 츄어블 비타민D 2000IU 90캡슐, 300mg</div>, <div class="name">일양약품 프라임 종합비타민미네랄 플러스 영양제, 180정, 1개</div>, <div class="name">Nature's Way 얼라이브! 원스 데일리 우먼 울트라 포텐시 멀티-비타민 타블렛, 60개입, 1개</div>, <div class="name">종근당건강 원데이21 멀티비타민 &amp; 미네랄, 60정, 1개</div>, <div class="name">자미에슨 츄어블 멀티비타민 앤 미네랄, 60정, 1개</div>, <div class="name">고려은단 비타민C 1000 이지, 180정, 1개</div>, <div class="name">비타할로 영양제 비타민D 2000IU, 90정, 1개</div>, <div class="name">비타할로 키즈 츄어블 멀티비타민 포도맛, 60정, 1개</div>, <div class="name">엔젯오리진 비타프레쉬 귤젤리 비타민C &amp; D 3000, 70정, 2개</div>, <div class="name">센트룸 포 맨 멀티비타민 미네랄, 70정, 1개</div>, <div class="name">세노비스 Advanced 트리플러스 멀티비타민, 100캡슐, 1개</div>, <div class="name">Nature's Way 얼라이브! 원스 데일리 울트라 포텐시 멀티 비타민 타블렛 2종 세트, 120개입, 1개</div>, <div class="name">비타민 다채, 300g, 1봉</div>, <div class="name">얼라이브 원스데일리 멀티비타민 60정, 104g, 1개</div>, <div class="name">센트룸 멀티 비타민 포 우먼, 70정, 1개</div>, <div class="name">비타할로 영양제 비타민C 1000, 180정, 1개</div>, <div class="name">뉴트리디데이 프리미엄 멀티비타민 골드 90정, 1개</div>, <div class="name">통라이프 종합비타민 ABCDE 앤 미네랄, 300정, 1개</div>, <div class="name">Nature's Way 얼라이브! 원스 데일리 우먼 50+ 울트라 포텐시 멀티-비타민 타블렛, 60개입, 1개</div>, <div class="name">종근당 칼슘 앤 마그네슘 비타민D 아연, 180정, 2개</div>, <div class="name">엔젯오리진 비타프레쉬 비타민 C&amp;D 3000, 70정, 1개</div>, <div class="name">솔가 네이처바이트 종합비타민 위드 미네랄, 90정, 1개</div>, <div class="name">고려은단 비타민C 골드 플러스 + 쇼핑백, 150정, 1개</div>, <div class="name">Nature's Way 얼라이브! 멀티-비타민 어덜트 구미, 90개입, 1개</div>, <div class="name">홀리데이즈 멀티비타민13 &amp; 미네랄6, 90정, 1개</div>, <div class="name">광동제약 비타500 데일리 스틱, 2g, 70개</div>, <div class="name">솔가 B-컴플렉스 "100" 베지터블 캡슐, 100개입, 1개</div>, <div class="name">비타민마을 메가씨 3000 비타민C 분말 스틱, 3g, 90개입</div>]
# 뉴트리원 멀티비타민+미네랄+오메가3 3중 복합기능성 기초 건강 종합 영양제 + 활력환, 2box
#
#
# 비타할로 온가족 멀티비타민 플러스 미네랄, 60정, 1개
#
#
# 얼라이브 원스데일리 멀티비타민, 60정, 1개
#
#
# 종근당건강 원데이21 멀티비타민 & 미네랄, 60정, 2개
#
#
# 닥터피플 쎈탁스 멀티 비타민 미네랄, 90정, 1개
#
#
# 대웅제약 에너씨슬 콜레다운, 30정, 2개
#
#
# 고려은단 비타민C 1000, 180정, 1개
#
#
# 네이쳐스웨이 얼라이브! 맨 울트라 포텐시 멀티 비타민 타블렛 60개입, 1개
#
#
# 한미 츄어블 비타민D 2000IU 90캡슐, 300mg
#
#
# 일양약품 프라임 종합비타민미네랄 플러스 영양제, 180정, 1개
#
#
# Nature's Way 얼라이브! 원스 데일리 우먼 울트라 포텐시 멀티-비타민 타블렛, 60개입, 1개
#
#
# 종근당건강 원데이21 멀티비타민 & 미네랄, 60정, 1개
#
#
# 자미에슨 츄어블 멀티비타민 앤 미네랄, 60정, 1개
#
#
# 고려은단 비타민C 1000 이지, 180정, 1개
#
#
# 비타할로 영양제 비타민D 2000IU, 90정, 1개
#
#
# 비타할로 키즈 츄어블 멀티비타민 포도맛, 60정, 1개
#
#
# 엔젯오리진 비타프레쉬 귤젤리 비타민C & D 3000, 70정, 2개
#
#
# 센트룸 포 맨 멀티비타민 미네랄, 70정, 1개
#
#
# 세노비스 Advanced 트리플러스 멀티비타민, 100캡슐, 1개
#
#
# Nature's Way 얼라이브! 원스 데일리 울트라 포텐시 멀티 비타민 타블렛 2종 세트, 120개입, 1개
#
#
# 비타민 다채, 300g, 1봉
#
#
# 얼라이브 원스데일리 멀티비타민 60정, 104g, 1개
#
#
# 센트룸 멀티 비타민 포 우먼, 70정, 1개
#
#
# 비타할로 영양제 비타민C 1000, 180정, 1개
#
#
# 뉴트리디데이 프리미엄 멀티비타민 골드 90정, 1개
#
#
# 통라이프 종합비타민 ABCDE 앤 미네랄, 300정, 1개
#
#
# Nature's Way 얼라이브! 원스 데일리 우먼 50+ 울트라 포텐시 멀티-비타민 타블렛, 60개입, 1개
#
#
# 종근당 칼슘 앤 마그네슘 비타민D 아연, 180정, 2개
#
#
# 엔젯오리진 비타프레쉬 비타민 C&D 3000, 70정, 1개
#
#
# 솔가 네이처바이트 종합비타민 위드 미네랄, 90정, 1개
#
#
# 고려은단 비타민C 골드 플러스 + 쇼핑백, 150정, 1개
#
#
# Nature's Way 얼라이브! 멀티-비타민 어덜트 구미, 90개입, 1개
#
#
# 홀리데이즈 멀티비타민13 & 미네랄6, 90정, 1개
#
#
# 광동제약 비타500 데일리 스틱, 2g, 70개
#
#
# 솔가 B-컴플렉스 "100" 베지터블 캡슐, 100개입, 1개
#
#
# 비타민마을 메가씨 3000 비타민C 분말 스틱, 3g, 90개입

# %%
# 학습목표 2: 텍스트를 추출하여 txt 형식으로 저장하기
# Step 5. 현재 페이지에 있는 내용을 txt 형식으로 파일에 저장하기
orig_stdout = sys.stdout
f = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = f
time.sleep(1)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
content_list = soup.find_all('div','name')

for i in content_list:
    print(i.text.strip())
    print("\n")
    
sys.stdout = orig_stdout
f.close()

print(" 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다")
# Out:
#  요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
