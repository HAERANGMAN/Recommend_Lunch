# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from urllib.request import urlopen
from urllib.parse import quote_plus

import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os
import urllib.request

rjatordj= input('    1.검색어 입력:')
sec_name=rjatordj

# cnt = int(input('    2.해당 분야에서 크롤링 할 건수는 몇건입니까?(1-50 건 사이 입력): '))

# 폴더
vhfxj=input("    2.홍명->##_, 해랑->##_")

if vhfej=='tprtm1':
 f_dir=r'C:\Users\Cadeau\Desktop'
else :
 f_dir=r'C:\Users\201210961\Desktop'

# sjaqj= int(input('    3.시작 숫자: '))
                
# f_dir =r'C:\Users\201210961\Desktop'

query_txt='iherb'
query_url='http://www.iherb.com'

now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt+'-'+sec_name)
os.chdir(f_dir+s+'-'+query_txt+'-'+sec_name)

ff_dir=f_dir+s+'-'+query_txt+'-'+sec_name
fx_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.xls'

s_time = time.time( )

chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
chrome_driver = r"C:\Users\201210961\Desktop\Coding\Python Webscraping\chromedriver_win32\chromedriver.exe" 
driver = webdriver.Chrome(chrome_driver, options=chrome_options)

driver.get(query_url)
time.sleep(0.5)

driver.find_element_by_xpath('//*[@id="txtSearch"]').send_keys(rjatordj)
driver.find_element_by_xpath('//*[@id="txtSearch"]').send_keys(Keys.ENTER)
time.sleep(0.5)

def scroll_down(driver):
      
      driver.execute_script("window.scrollBy(0,9300);")
      time.sleep(0.5)

scroll_down(driver)

# 비트맵 이미지 아이콘을 위한 대체 딕셔너리를 만듭니다
bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# 링크
fldzm=[ ]
# 이름 
dlfma=[ ]
# 가격
rkrur=[ ]
# 무게
anrp=[ ]
# 번호
no2=[]
no=sjaqj
# 이미지1
img1=[]
# 이미지2
img2=[]

fldzmm=soup.find_all('a', class_='absolute-link product-link')

for link in fldzmm:
    fldzm.append(link.get('href'))

# print(fldzm)

# 1면따오기
# for link in soup.find_all('a', class_='absolute-link product-link'):
#     fldzm.append(link.get('href'))
#     print(fldzm)
    
# 링크 각개전투
for link in fldzm:
    driver.get(link)
    time.sleep(0.2)
    html2 = driver.page_source
    soup2 = BeautifulSoup(html2, 'html.parser')
    
    try :
     dlfmaa=soup2.find('h1',id='name').get_text()
    except AttributeError:
     dlfmaa=''
    else:
     dlfma.append(dlfmaa)

    try :
     rkrurr=soup2.find('div',id='price').get_text().strip()
    except AttributeError:
     rkrurr=''
    else:
     rkrur.append(rkrurr)

    try :
     anrpp=soup2.find('span',class_='product-weight').get_text().strip()
    except AttributeError:
     anrpp=''
    else:
     anrp.append(anrpp)
    
    try :
     img11=soup2.find('div', 'thumbnail-container').img['data-large-img']
    except AttributeError:
     img11=''
    else:
     img1.append(img11)
    
    try :
     img22=soup2.select('div .thumbnail-container > img')[1]['data-large-img']
    except IndexError:
     img22=''
    else:
     img2.append(img22)
  

# img.append(soup.find('div', 'thumbnail-container').img['data-large-img'])
# img.append(soup.select('div .thumbnail-container > img')[1]['data-large-img'])  
        
# print(fldzm)
# print(dlfma)
# print(rkrur)
# print(anrp)

#Step 5. 검색 결과를 다양한 형태로 저장하기
              
iherb = pd.DataFrame()
iherb['번호']=no2
iherb['링크']=pd.Series(fldzm)
iherb['이름']=pd.Series(dlfma)
iherb['가격']=pd.Series(rkrur)
iherb['무게']=pd.Series(anrp)
iherb['이미지1']=pd.Series(img1)
iherb['이미지2']=pd.Series(img2)

# 엑셀 형태로 저장하기
orig_stdout = sys.stdout
iherb.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time

# Step 6. 요약 정보를 출력하기
print("\n")
print("=" *50)
print("총 소요시간은 %s 초입니다" %t_time)
print('%s를 확인하세요! 쎆쓰!' %f_dir)
print("=" *50)

# sys.stdout = orig_stdout
# f.close( )

# print("\n") 
# print("=" *80)
# # print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
# print("2.총 소요시간은 %s 초 입니다" %round(t_time,1))
# print("=" *80)    

# # driver.switch_to_window(driver.window_handles[1]) 
# driver.get_window_position(driver.window_handles[1])
# Out:
#     1.검색어 입력:inositol
#     2.해당 분야에서 크롤링 할 건수는 몇건입니까?(1-50 건 사이 입력): 1
#     3.파일을 저장할 폴더명만 쓰세요(예:c:\temp\):c:\temp\
# ['https://www.iherb.com/pr/Fairhaven-Health-Myo-Inositol-For-Women-and-Men-120-Capsules/62649', 'https://www.iherb.com/pr/Jarrow-Formulas-Inositol-750-mg-100-Veggie-Caps/192', 'https://www.iherb.com/pr/Now-Foods-Inositol-Capsules-500-mg-100-Veg-Capsules/684', 'https://www.iherb.com/pr/Lake-Avenue-Nutrition-Inositol-Powder-Unflavored-16-oz-454-g/96322', 'https://www.iherb.com/pr/Now-Foods-Choline-Inositol-100-Veg-Capsules/513', 'https://www.iherb.com/pr/Source-Naturals-Inositol-Choline-800-mg-100-Tablets/1335', 'https://www.iherb.com/pr/Solgar-Choline-Inositol-100-Vegetable-Capsules/15507', 'https://www.iherb.com/pr/Solgar-Inositol-500-mg-100-Vegetable-Capsules/48587', 'https://www.iherb.com/pr/Nature-s-Way-Choline-Inositol-1-000-mg-100-Capsules/1882', 'https://www.iherb.com/pr/Nature-s-Way-Inositol-Once-Daily-500-mg-100-Capsules/1912', 'https://www.iherb.com/pr/Jarrow-Formulas-Inositol-Powder-8-oz-227-g/126', 'https://www.iherb.com/pr/Life-Extension-Inositol-Caps-1-000-mg-360-Vegetarian-Capsules/47342', 'https://www.iherb.com/pr/Now-Foods-Inositol-Powder-8-oz-227-g/13813', 'https://www.iherb.com/pr/Now-Foods-Inositol-Powder-4-oz-113-g/678', 'https://www.iherb.com/pr/Now-Foods-Inositol-Powder-1-lb-454-g/43479', 'https://www.iherb.com/pr/Jarrow-Formulas-IP6-Inositol-Hexaphosphate-500-mg-120-Veggie-Caps/190', 'https://www.iherb.com/pr/Now-Foods-Magnesium-Inositol-Relax-Lemonade-16-oz-454-g/73624', 'https://www.iherb.com/pr/Nature-s-Way-Cell-Fort-IP-6-Inositol-Ultra-Strength-Powder-Citrus-Flavored-14-6-oz-414-g/2122', 'https://www.iherb.com/pr/Protocol-for-Life-Balance-Myo-Inositol-Powder-1-lb-454-g/81745', 'https://www.iherb.com/pr/Nature-s-Way-Cell-Fort-IP-6-Inositol-120-Vegan-Capsules/38974', 'https://www.iherb.com/pr/Nature-s-Way-Cell-Fort-IP-6-Inositol-240-Vegan-Capsules/2233', 'https://www.iherb.com/pr/Source-Naturals-Pure-Inositol-Powder-8-oz-226-8-g/1319', 'https://www.iherb.com/pr/Now-Foods-Flush-Free-Niacin-250-mg-180-Veg-Capsules/697', 'https://www.iherb.com/pr/Life-Extension-No-Flush-Niacin-800-mg-100-Capsules/37900']
#
#
# ==================================================
# 총 소요시간은 86.04194784164429 초입니다
# ==================================================

# %%
# find_element_by_id
# find_element_by_name
# find_element_by_xpath
# find_element_by_link_text
# find_element_by_partial_link_text
# find_element_by_tag_name
# find_element_by_class_name
# find_element_by_css_selector
# ----------------(단수//복수)------------------
# find_elements_by_name
# find_elements_by_xpath
# find_elements_by_link_text
# find_elements_by_partial_link_text
# find_elements_by_tag_name
# find_elements_by_class_name
# find_elements_by_css_selector
# ---------------------------------------------------------
# # 가격을 가져올때(첫 번째 꺼 하나만)
# soup.select('p > span.price')[0].text   
# ※ [0] 을 통해 첫 번째에 나오는 값이라고 한정 시켜줌. 중요!!!!

# # 가격을 가져올때(복수)
# prices = soup.select('p > span.price')
# for price in prices:        # 복수의 가격 정보들에서 하나씩 꺼내어
#     print(price.text)       # 텍스트만 화면에 출력한다

# 속성를 가져올때(첫 번째 꺼 하나만)
# select('a')[0]['href']
# ---------------------------------------------------------
